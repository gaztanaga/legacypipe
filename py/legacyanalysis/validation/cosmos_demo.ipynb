# %% [markdown]
# Cosmos (2 deg2 at ra,dec = 150,2)
# ========
#
# 0.5x0.5 deg region centered on Cosmos in Dustin Lang's [Legacy Viewer](http://legacysurvey.org/viewer):
# ![BMH](http://portal.nersc.gov/project/desi/users/kburleigh/cosmos_legacyviewer.png)

# %%
import sys
sys.executable
# Out:
# '/anaconda2/bin/python'

# %%
sys.path.append('/project/projectdirs/desi/users/burleigh/theValidator_root/repo/legacypipe/py')
sys.path
# Out:
# ['',
#  '/anaconda2/lib/python27.zip',
#  '/anaconda2/lib/python2.7',
#  '/anaconda2/lib/python2.7/plat-linux2',
#  '/anaconda2/lib/python2.7/lib-tk',
#  '/anaconda2/lib/python2.7/lib-old',
#  '/anaconda2/lib/python2.7/lib-dynload',
#  '/global/homes/k/kaylanb/.local/lib/python2.7/site-packages',
#  '/anaconda2/lib/python2.7/site-packages',
#  '/anaconda2/lib/python2.7/site-packages/Sphinx-1.4.1-py2.7.egg',
#  '/anaconda2/lib/python2.7/site-packages/setuptools-23.0.0-py2.7.egg',
#  '/anaconda2/lib/python2.7/site-packages/IPython/extensions',
#  '/global/u2/k/kaylanb/.ipython',
#  '/project/projectdirs/desi/users/burleigh/theValidator_root/repo/legacypipe/py']

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division, print_function

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import argparse
import pickle
import scipy.stats as st
from scipy.optimize import curve_fit as cu
from astropy.io import fits

from legacyanalysis.validation.pathnames import get_indir,get_outdir,make_dir
from legacyanalysis.validation.cosmos_demo import cosmos_plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cosmos_plots(show=True)
# Out:
# /project/projectdirs/desi/users/burleigh/theValidator_root/repo/legacypipe/py/legacyanalysis/validation/cosmos_demo.py:55: RuntimeWarning: divide by zero encountered in log10
#   g_mag_dr2 = 22.5 - 2.5 * np.log10(dr2['decam_flux_2'].T[1] / dr2['decam_mw_transmission_2'].T[1])
# /project/projectdirs/desi/users/burleigh/theValidator_root/repo/legacypipe/py/legacyanalysis/validation/cosmos_demo.py:55: RuntimeWarning: invalid value encountered in log10
#   g_mag_dr2 = 22.5 - 2.5 * np.log10(dr2['decam_flux_2'].T[1] / dr2['decam_mw_transmission_2'].T[1])
# /project/projectdirs/desi/users/burleigh/theValidator_root/repo/legacypipe/py/legacyanalysis/validation/cosmos_demo.py:56: RuntimeWarning: divide by zero encountered in log10
#   r_mag_dr2 = 22.5 - 2.5 * np.log10(dr2['decam_flux_2'].T[2] / dr2['decam_mw_transmission_2'].T[2])
# ...
